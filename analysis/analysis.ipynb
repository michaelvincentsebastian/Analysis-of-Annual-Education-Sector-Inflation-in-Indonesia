# %% [markdown]
# import module

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# import datasets

# %%
df24 = pd.read_excel(r'B:\GitHub Repository\Analysis-of-Annual-Education-Sector-Inflation-in-Indonesia\datasets\2024.xlsx', skiprows=1)
df25 = pd.read_excel(r'B:\GitHub Repository\Analysis-of-Annual-Education-Sector-Inflation-in-Indonesia\datasets\2025.xlsx', skiprows=1)

# %% [markdown]
# setting row col size

# %%
pd.set_option('display.max.rows', 10)
pd.set_option('display.max.columns', 100)

# %%
df25
# Out:
#           Unnamed: 0  \
# 0                NaN
# 1                NaN
# 2                NaN
# 3    KAB ACEH TENGAH
# 4           MEULABOH
# ..               ...
# 149          MERAUKE
# 150           TIMIKA
# 151       KAB NABIRE
# 152   KAB JAYAWIJAYA
# 153        INDONESIA
#
#     Inflasi Tahunan (Y-on-Y) (2022=100) Menurut Kelompok dan Sub Kelompok 09 Pendidikan (Persen)  \
# 0                                           Pendidikan
# 1                                                 2025
# 2                                              Januari
# 3                                                 0.07
# 4                                                 0.03
# ..                                                 ...
# 149                                              -2.17
# 150                                               1.09
# 151                                               1.96
# 152                                               1.82
# ...

# %% [markdown]
# drop index 1 (disini index 1 = Tahun, yang dimana kurang berguna jika ditaruh di posisi itu karena tidak bisa di analisa)

# %%
df25.drop(df25.index[1], inplace=True)
df24.drop(df24.index[1], inplace=True)

# %%
df25
# Out:
#            Unnamed: 0  \
# 0                 NaN
# 3     KAB ACEH TENGAH
# 4            MEULABOH
# 5    KAB ACEH TAMIANG
# 6     KOTA BANDA ACEH
# ..                ...
# 149           MERAUKE
# 150            TIMIKA
# 151        KAB NABIRE
# 152    KAB JAYAWIJAYA
# 153         INDONESIA
#
#     Inflasi Tahunan (Y-on-Y) (2022=100) Menurut Kelompok dan Sub Kelompok 09 Pendidikan (Persen)  \
# 0                                           Pendidikan
# 3                                                 0.07
# 4                                                 0.03
# 5                                                 5.14
# 6                                                 0.58
# ..                                                 ...
# 149                                              -2.17
# 150                                               1.09
# 151                                               1.96
# 152                                               1.82
# ...

# %%
df24
# Out:
#            Unnamed: 0  \
# 0                 NaN
# 2                 NaN
# 3     KAB ACEH TENGAH
# 4            MEULABOH
# 5    KAB ACEH TAMIANG
# ..                ...
# 149           MERAUKE
# 150            TIMIKA
# 151        KAB NABIRE
# 152    KAB JAYAWIJAYA
# 153         INDONESIA
#
#     Inflasi Tahunan (Y-on-Y) (2022=100) Menurut Kelompok dan Sub Kelompok 09 Pendidikan (Persen)  \
# 0                                           Pendidikan
# 2                                              Januari
# 3                                                    0
# 4                                                 2.79
# 5                                                 2.36
# ..                                                 ...
# 149                                               2.77
# 150                                                  0
# 151                                               0.54
# 152                                                  0
# ...

# %%
df24['Tahun'] = 2024
df25['Tahun'] = 2025

# %%
df25
# Out:
#            Unnamed: 0  \
# 0                 NaN
# 3     KAB ACEH TENGAH
# 4            MEULABOH
# 5    KAB ACEH TAMIANG
# 6     KOTA BANDA ACEH
# ..                ...
# 149           MERAUKE
# 150            TIMIKA
# 151        KAB NABIRE
# 152    KAB JAYAWIJAYA
# 153         INDONESIA
#
#     Inflasi Tahunan (Y-on-Y) (2022=100) Menurut Kelompok dan Sub Kelompok 09 Pendidikan (Persen)  \
# 0                                           Pendidikan
# 3                                                 0.07
# 4                                                 0.03
# 5                                                 5.14
# 6                                                 0.58
# ..                                                 ...
# 149                                              -2.17
# 150                                               1.09
# 151                                               1.96
# 152                                               1.82
# ...

# %%
df24
# Out:
#            Unnamed: 0  \
# 0                 NaN
# 2                 NaN
# 3     KAB ACEH TENGAH
# 4            MEULABOH
# 5    KAB ACEH TAMIANG
# ..                ...
# 149           MERAUKE
# 150            TIMIKA
# 151        KAB NABIRE
# 152    KAB JAYAWIJAYA
# 153         INDONESIA
#
#     Inflasi Tahunan (Y-on-Y) (2022=100) Menurut Kelompok dan Sub Kelompok 09 Pendidikan (Persen)  \
# 0                                           Pendidikan
# 2                                              Januari
# 3                                                    0
# 4                                                 2.79
# 5                                                 2.36
# ..                                                 ...
# 149                                               2.77
# 150                                                  0
# 151                                               0.54
# 152                                                  0
# ...

# %%
df_combined = pd.concat([df24, df25], ignore_index=True)

# %%
df_combined
# Out:
#            Unnamed: 0  \
# 0                 NaN
# 1                 NaN
# 2     KAB ACEH TENGAH
# 3            MEULABOH
# 4    KAB ACEH TAMIANG
# ..                ...
# 300           MERAUKE
# 301            TIMIKA
# 302        KAB NABIRE
# 303    KAB JAYAWIJAYA
# 304         INDONESIA
#
#     Inflasi Tahunan (Y-on-Y) (2022=100) Menurut Kelompok dan Sub Kelompok 09 Pendidikan (Persen)  \
# 0                                           Pendidikan
# 1                                              Januari
# 2                                                    0
# 3                                                 2.79
# 4                                                 2.36
# ..                                                 ...
# 300                                              -2.17
# 301                                               1.09
# 302                                               1.96
# 303                                               1.82
# ...

# %%
print("Data gabungan sebelum pembersihan (5 baris pertama):")
print(df_combined.head())
print("\nData gabungan sebelum pembersihan (5 baris terakhir):")
print(df_combined.tail())
# Out:
# Data gabungan sebelum pembersihan (5 baris pertama):
#          Unnamed: 0  \
# 0               NaN
# 1               NaN
# 2   KAB ACEH TENGAH
# 3          MEULABOH
# 4  KAB ACEH TAMIANG
#
#   Inflasi Tahunan (Y-on-Y) (2022=100) Menurut Kelompok dan Sub Kelompok 09 Pendidikan (Persen)  \
# 0                                         Pendidikan
# 1                                            Januari
# 2                                                  0
# 3                                               2.79
# 4                                               2.36
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1   Februari      Maret      April        Mei       Juni       Juli
# 2          0          0       0.19       0.19       0.19       0.19
# 3       2.26       1.81        0.7        0.7        0.7        0.7
# 4       2.36       2.36       2.36       2.36       2.36       1.39
#
# ...

# %%
kolom_bulan = ['Januari', 'Februari', 'Maret', 'April', 'Mei', 'Juni',
               'Juli', 'Agustus', 'September', 'Oktober', 'November', 'Desember']

# %%
kolom_bulan_exist = [col for col in kolom_bulan if col in df_combined.columns]
# Out:
# []

# %%
df_combined = pd.concat([df24, df25], ignore_index=True)
