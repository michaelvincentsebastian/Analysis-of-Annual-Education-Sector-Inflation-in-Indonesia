# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'B:\GitHub Repository\Analysis-of-Annual-Education-Sector-Inflation-in-Indonesia\cleaning\cleaned-df.csv')

# %%
df.fillna('', inplace=True)
df
# Out:
#            Unnamed: 0 Pendidikan Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                        Januari   Februari      Maret      April        Mei
# 1     KAB ACEH TENGAH        0.0          0          0       0.19       0.19
# 2            MEULABOH       2.79       2.26       1.81        0.7        0.7
# 3    KAB ACEH TAMIANG       2.36       2.36       2.36       2.36       2.36
# 4     KOTA BANDA ACEH       0.32       0.35       0.35       0.35       0.35
# ..                ...        ...        ...        ...        ...        ...
# 298           MERAUKE      -2.17      -2.17      -2.17      -2.17      -2.17
# 299            TIMIKA       1.09       1.09       1.09       1.09       1.09
# 300        KAB NABIRE       1.96        2.3        2.3        2.3        2.3
# 301    KAB JAYAWIJAYA       1.82       3.15       3.15       3.15       3.15
# 302         INDONESIA       2.05       2.04       1.89       1.88       1.88
#
# ...

# %%
# Set the first row (index 0) as column headers and drop it from the data
df.columns = [df.iloc[0]]
df = df.iloc[1:].reset_index(drop=True)

# %%
df
# Out:
# 0                     Januari Februari  Maret  April    Mei   Juni  Juli  \
# 0     KAB ACEH TENGAH     0.0        0      0   0.19   0.19   0.19  0.19
# 1            MEULABOH    2.79     2.26   1.81    0.7    0.7    0.7   0.7
# 2    KAB ACEH TAMIANG    2.36     2.36   2.36   2.36   2.36   2.36  1.39
# 3     KOTA BANDA ACEH    0.32     0.35   0.35   0.35   0.35   0.35  0.35
# 4    KOTA LHOKSEUMAWE    1.27     1.27   1.27   1.27   1.27   1.27  3.42
# ..                ...     ...      ...    ...    ...    ...    ...   ...
# 297           MERAUKE   -2.17    -2.17  -2.17  -2.17  -2.17  -2.17     -
# 298            TIMIKA    1.09     1.09   1.09   1.09   1.09    0.2     -
# 299        KAB NABIRE    1.96      2.3    2.3    2.3    2.3    2.3     -
# 300    KAB JAYAWIJAYA    1.82     3.15   3.15   3.15   3.15   3.15     -
# 301         INDONESIA    2.05     2.04   1.89   1.88   1.88   1.82     -
#
# 0   Agustus September  ...   Mei  Juni  Juli Agustus September Oktober  \
# ...

# %%
df.columns(contains='Unnamed')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.columns(contains='Unnamed')
#
# TypeError: 'MultiIndex' object is not callable
