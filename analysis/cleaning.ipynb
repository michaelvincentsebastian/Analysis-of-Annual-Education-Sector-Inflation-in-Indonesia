# %%
import pandas as pd
import numpy as np

# %%
df24 = pd.read_excel(r'B:\GitHub Repository\Analysis-of-Annual-Education-Sector-Inflation-in-Indonesia\datasets\2024.xlsx', skiprows=1, header=[0, 2])
df25 = pd.read_excel(r'B:\GitHub Repository\Analysis-of-Annual-Education-Sector-Inflation-in-Indonesia\datasets\2025.xlsx', skiprows=1, header=[0, 2])

# %%
df25
# Out:
#     Unnamed: 0_level_0  \
#     Unnamed: 0_level_1
# 0                  NaN
# 1      KAB ACEH TENGAH
# 2             MEULABOH
# 3     KAB ACEH TAMIANG
# 4      KOTA BANDA ACEH
# ..                 ...
# 147            MERAUKE
# 148             TIMIKA
# 149         KAB NABIRE
# 150     KAB JAYAWIJAYA
# 151          INDONESIA
#
#     Inflasi Tahunan (Y-on-Y) (2022=100) Menurut Kelompok dan Sub Kelompok 09 Pendidikan (Persen)  \
#                                                                                             2025
# 0                                              Januari
# 1                                                 0.07
# 2                                                 0.03
# 3                                                 5.14
# 4                                                 0.58
# ..                                                 ...
# 147                                              -2.17
# 148                                               1.09
# ...

# %%
df25.columns = [f"{col1}_{col2}".strip("_") for col1, col2 in df25.columns]

# %%
df25
# Out:
#     Unnamed: 0_level_0_Unnamed: 0_level_1  \
# 0                                     NaN
# 1                         KAB ACEH TENGAH
# 2                                MEULABOH
# 3                        KAB ACEH TAMIANG
# 4                         KOTA BANDA ACEH
# ..                                    ...
# 147                               MERAUKE
# 148                                TIMIKA
# 149                            KAB NABIRE
# 150                        KAB JAYAWIJAYA
# 151                             INDONESIA
#
#     Inflasi Tahunan (Y-on-Y) (2022=100) Menurut Kelompok dan Sub Kelompok 09 Pendidikan (Persen)_2025  \
# 0                                              Januari
# 1                                                 0.07
# 2                                                 0.03
# 3                                                 5.14
# 4                                                 0.58
# ..                                                 ...
# ...
